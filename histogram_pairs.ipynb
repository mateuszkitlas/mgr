# %%
# %load_ext autoreload
# %autoreload 2
from main.stats import main, histogram_pairs

main(histogram_pairs)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# <span style='font-family:monospace'>source, stat_fn, score</span> - displayed on figure
# <pre>
# for every node in source:
#   for every (x,y) in node.children:
#     where
#       x = solvable inner node, represended on x-axis
#       y = not solvable node, represented on y-axis
#     for score in [sa, sc, ra, mf, syba, ai]:
#       # if score==ai: avg == min == max
#       for stat_fn in [<span style='color:blue'>min</span>, <span style='color:red'>max</span>, <span style='color:green'>avg</span>]:
#         point = f(x) - f(y)
#         where
#           fun(node) = stat_fn([score(mol) for mol in node.expandable])
#           node.expandable are not solved molecules (not available in stock)
# </pre>
# too little data in source=Cholesterol; {'solved': 0, 'not solved': 1, 'inodes': 0}
# too little data in source=Morphine; {'solved': 0, 'not solved': 1, 'inodes': 0}
# ...
